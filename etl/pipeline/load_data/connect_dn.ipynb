# %%
import os
import pandas as pd
from sqlalchemy import create_engine
from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv()
# Out:
# True

# %%
# Database connection details
DB_USER = os.getenv('POSTGRES_USER')
DB_PASSWORD = os.getenv('POSTGRES_PASSWORD')
DB_NAME = os.getenv('POSTGRES_DB')
DB_HOST = os.getenv('DB_HOST', 'localhost')  # Use 'localhost' if running Jupyter on the host machine
DB_PORT = os.getenv('DB_PORT', 5432)

# Create database engine
engine = create_engine(f'postgresql://{DB_USER}:{DB_PASSWORD}@{DB_HOST}:{DB_PORT}/{DB_NAME}')

# %%
query = """
SELECT table_name
FROM information_schema.tables
WHERE table_schema = 'public'
"""

# Execute the query and load the result into a DataFrame
df = pd.read_sql(query, engine)

# Display the DataFrame
df.head()
# Out:
#               table_name
# 0          business_info
# 1            names_table
# 2  business_name_history
# 3              addresses
# 4          company_forms

# %%
query = "SELECT * FROM business_info"

# Execute the query and load the result into a DataFrame
df = pd.read_sql(query, engine)

df.head()
# Out:
#   business_id registration_date             eu_id  \
# 0   0150953-8        1978-03-15  FIFPRO.0150953-8
# 1   0151464-4        1978-03-15           unknown
# 2   0151470-8        1978-03-15           unknown
# 3   0151481-2        1978-03-15  FIFPRO.0151481-2
# 4   0151484-7        1978-03-15  FIFPRO.0151484-7
#
#                       primary_name  \
# 0                   Geoanalyysi Oy
# 1               Markku J Takala Ky
# 2     Eero Kaski Kommandiittiyhtiö
# 3         Nokian Metallirakenne Oy
# 4  Rounionkadun Teollisuushalli Oy
#
#                                   main_business_line  status end_date  \
# 0                       Civil engineering activities  Active     None
# 1                       Letting of other real estate  Active     None
# 2                                              CafÚs  Active     None
# 3  Manufacture of metal structures and parts of s...  Active     None
# 4                       Letting of other real estate  Active     None
#
#         last_modified  website
# 0 2024-11-15 17:23:08  unknown
# 1 2024-02-02 10:56:49  unknown
# 2 2024-04-03 09:11:46  unknown
# 3 2024-11-12 18:31:14  unknown
# 4 2024-02-02 10:51:06  unknown

# %%
query = "SELECT * FROM names_table"

# Execute the query and load the result into a DataFrame
df = pd.read_sql(query, engine)

# Display the DataFrame
df.head()
# Out:
#    id business_id                             name  \
# 0   1   0150953-8                   Geoanalyysi Oy
# 1   2   0151464-4               Markku J Takala Ky
# 2   3   0151464-4  Autosähköliike Markku Takala Ky
# 3   4   0151470-8     Eero Kaski Kommandiittiyhtiö
# 4   5   0151481-2         Nokian Metallirakenne Oy
#
#                           type registration_date  name_version start_date  \
# 0  Business Name (Sole Trader)        1976-10-22             1       None
# 1  Business Name (Sole Trader)        2016-12-21             1       None
# 2  Business Name (Sole Trader)        1993-03-03             2       None
# 3  Business Name (Sole Trader)        1974-06-07             1       None
# 4  Business Name (Sole Trader)        1996-09-03             1       None
#
#      end_date  is_active
# 0        None       True
# 1        None       True
# 2  2016-12-21       True
# 3        None       True
# 4        None       True

# %%
query = "SELECT * FROM business_name_history"

# Execute the query and load the result into a DataFrame
df = pd.read_sql(query, engine)

# Display the DataFrame
df.head()
# Out:
#   business_id                      previous_name  \
# 0   0151464-4    Autosähköliike Markku Takala Ky
# 1   0151481-2           Nokian Metallirakenne Ky
# 2   0151484-7  Nokian Rakennuspelti, avoin yhtiö
# 3   0151535-6        Nokian Hakan vuokratalot Oy
# 4   0151608-4                 As. Oy Alhonkallio
#
#                             new_name change_date
# 0    Autosähköliike Markku Takala Ky  2016-12-21
# 1           Nokian Metallirakenne Ky  1996-09-02
# 2  Nokian Rakennuspelti, avoin yhtiö  1996-11-25
# 3        Nokian Hakan vuokratalot Oy  1982-06-16
# 4                 As. Oy Alhonkallio  1982-06-23

# %%
query = "SELECT * FROM company_forms_table"

# Execute the query and load the result into a DataFrame
df = pd.read_sql(query, engine)

# Display the DataFrame
df.head()
# Out:
#   business_id          description registration_date end_date
# 0   0150953-8      Limited company              None     None
# 1   0151464-4  Limited partnership              None     None
# 2   0151470-8  Limited partnership              None     None
# 3   0151481-2      Limited company        1996-09-03     None
# 4   0151484-7      Limited company        1996-11-26     None

# %%
query = "SELECT * FROM registered_entries_table"

# Execute the query and load the result into a DataFrame
df = pd.read_sql(query, engine)

# Display the DataFrame
df.head()
# Out:
#   business_id   description registration_date  \
# 0   3381556-4  Unregistered        2023-08-06
# 1   3381556-4    Registered        2023-08-18
# 2   3381556-4    Registered        2023-08-18
# 3   3382714-3  Unregistered        2023-08-11
# 4   3382714-3    Registered        2023-08-24
#
#                                         register  \
# 0                                 Trade Register
# 1                                 Trade Register
# 2  Basic Information from the Tax Administration
# 3                                 Trade Register
# 4                                 Trade Register
#
#                         authority
# 0  Patent and Registration Office
# 1  Patent and Registration Office
# 2              Tax Administration
# 3  Patent and Registration Office
# 4  Patent and Registration Office
